# %% [markdown]
# #  WALKTHROUGH

# %%
import pandas as pd

# %%
df=pd.read_csv("BlackFriday.csv")

# %%
df
# Out:
#         User_ID Product_ID Gender    Age  Occupation City_Category  \
# 0       1000001  P00069042      F   0-17          10             A
# 1       1000001  P00248942      F   0-17          10             A
# 2       1000001  P00087842      F   0-17          10             A
# 3       1000001  P00085442      F   0-17          10             A
# 4       1000002  P00285442      M    55+          16             C
# ...         ...        ...    ...    ...         ...           ...
# 537572  1004737  P00193542      M  36-45          16             C
# 537573  1004737  P00111142      M  36-45          16             C
# 537574  1004737  P00345942      M  36-45          16             C
# 537575  1004737  P00285842      M  36-45          16             C
# 537576  1004737  P00118242      M  36-45          16             C
#
#        Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                               2               0                   3
# ...

# %%
df.head()
# Out:
#    User_ID Product_ID Gender   Age  Occupation City_Category  \
# 0  1000001  P00069042      F  0-17          10             A
# 1  1000001  P00248942      F  0-17          10             A
# 2  1000001  P00087842      F  0-17          10             A
# 3  1000001  P00085442      F  0-17          10             A
# 4  1000002  P00285442      M   55+          16             C
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                          2               0                   3
# 1                          2               0                   1
# 2                          2               0                  12
# 3                          2               0                  12
# 4                         4+               0                   8
#
#    Product_Category_2  Product_Category_3  Purchase
# 0                 NaN                 NaN      8370
# 1                 6.0                14.0     15200
# ...

# %%
df.isnull()
# Out:
#         User_ID  Product_ID  Gender    Age  Occupation  City_Category  \
# 0         False       False   False  False       False          False
# 1         False       False   False  False       False          False
# 2         False       False   False  False       False          False
# 3         False       False   False  False       False          False
# 4         False       False   False  False       False          False
# ...         ...         ...     ...    ...         ...            ...
# 537572    False       False   False  False       False          False
# 537573    False       False   False  False       False          False
# 537574    False       False   False  False       False          False
# 537575    False       False   False  False       False          False
# 537576    False       False   False  False       False          False
#
#         Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# ...

# %%
df.isnull().sum()
# Out:
# User_ID                            0
# Product_ID                         0
# Gender                             0
# Age                                0
# Occupation                         0
# City_Category                      0
# Stay_In_Current_City_Years         0
# Marital_Status                     0
# Product_Category_1                 0
# Product_Category_2            166986
# Product_Category_3            373299
# Purchase                           0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 537577 entries, 0 to 537576
# Data columns (total 12 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   User_ID                     537577 non-null  int64
#  1   Product_ID                  537577 non-null  object
#  2   Gender                      537577 non-null  object
#  3   Age                         537577 non-null  object
#  4   Occupation                  537577 non-null  int64
#  5   City_Category               537577 non-null  object
#  6   Stay_In_Current_City_Years  537577 non-null  object
#  7   Marital_Status              537577 non-null  int64
#  8   Product_Category_1          537577 non-null  int64
#  9   Product_Category_2          370591 non-null  float64
#  10  Product_Category_3          164278 non-null  float64
#  11  Purchase                    537577 non-null  int64
# dtypes: float64(2), int64(5), object(5)
# ...

# %%
df.describe()
# Out:
#             User_ID    Occupation  Marital_Status  Product_Category_1  \
# count  5.375770e+05  537577.00000   537577.000000       537577.000000
# mean   1.002992e+06       8.08271        0.408797            5.295546
# std    1.714393e+03       6.52412        0.491612            3.750701
# min    1.000001e+06       0.00000        0.000000            1.000000
# 25%    1.001495e+06       2.00000        0.000000            1.000000
# 50%    1.003031e+06       7.00000        0.000000            5.000000
# 75%    1.004417e+06      14.00000        1.000000            8.000000
# max    1.006040e+06      20.00000        1.000000           18.000000
#
#        Product_Category_2  Product_Category_3       Purchase
# count       370591.000000       164278.000000  537577.000000
# mean             9.842144           12.669840    9333.859853
# std              5.087259            4.124341    4981.022133
# min              2.000000            3.000000     185.000000
# ...

# %%
del df['Product_Category_2']
del df['Product_Category_3']

# %%
df
# Out:
#         User_ID Product_ID Gender    Age  Occupation City_Category  \
# 0       1000001  P00069042      F   0-17          10             A
# 1       1000001  P00248942      F   0-17          10             A
# 2       1000001  P00087842      F   0-17          10             A
# 3       1000001  P00085442      F   0-17          10             A
# 4       1000002  P00285442      M    55+          16             C
# ...         ...        ...    ...    ...         ...           ...
# 537572  1004737  P00193542      M  36-45          16             C
# 537573  1004737  P00111142      M  36-45          16             C
# 537574  1004737  P00345942      M  36-45          16             C
# 537575  1004737  P00285842      M  36-45          16             C
# 537576  1004737  P00118242      M  36-45          16             C
#
#        Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                               2               0                   3
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 537577 entries, 0 to 537576
# Data columns (total 10 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   User_ID                     537577 non-null  int64
#  1   Product_ID                  537577 non-null  object
#  2   Gender                      537577 non-null  object
#  3   Age                         537577 non-null  object
#  4   Occupation                  537577 non-null  int64
#  5   City_Category               537577 non-null  object
#  6   Stay_In_Current_City_Years  537577 non-null  object
#  7   Marital_Status              537577 non-null  int64
#  8   Product_Category_1          537577 non-null  int64
#  9   Purchase                    537577 non-null  int64
# dtypes: int64(5), object(5)
# memory usage: 41.0+ MB

# %% [markdown]
# # ANALYSING COLUMNS

# %%
df['User_ID'].unique()
# Out:
# array([1000001, 1000002, 1000003, ..., 1004113, 1005391, 1001529],
#       dtype=int64)

# %%
df['User_ID'].nunique()
# Out:
# 5891

# %%
df['Product_ID'].unique()
# Out:
# array(['P00069042', 'P00248942', 'P00087842', ..., 'P00038842',
#        'P00295642', 'P00091742'], dtype=object)

# %%
df['Product_ID'].nunique()
# Out:
# 3623

# %%
df['Gender'].unique()
# Out:
# array(['F', 'M'], dtype=object)

# %%
df['Gender'].nunique()
# Out:
# 2

# %%
df['Age'].unique()
# Out:
# array(['0-17', '55+', '26-35', '46-50', '51-55', '36-45', '18-25'],
#       dtype=object)

# %%
df['Age'].nunique()
# Out:
# 7

# %%
df['Occupation'].unique()
# Out:
# array([10, 16, 15,  7, 20,  9,  1, 12, 17,  0,  3,  4, 11,  8, 19,  2, 18,
#         5, 14, 13,  6], dtype=int64)

# %%
df['Occupation'].nunique()
# Out:
# 21

# %%
df['City_Category'].unique()
# Out:
# array(['A', 'C', 'B'], dtype=object)

# %%
df['City_Category'].nunique()
# Out:
# 3

# %%
df['Stay_In_Current_City_Years'].unique()
# Out:
# array(['2', '4+', '3', '1', '0'], dtype=object)

# %%
df['Stay_In_Current_City_Years'].nunique()
# Out:
# 5

# %%
df['Marital_Status'].unique()
# Out:
# array([0, 1], dtype=int64)

# %%
df['Marital_Status'].nunique()
# Out:
# 2

# %%
df['Product_Category_1'].unique()
# Out:
# array([ 3,  1, 12,  8,  5,  4,  2,  6, 14, 11, 13, 15,  7, 16, 18, 10, 17,
#         9], dtype=int64)

# %%
df['Product_Category_1'].nunique()
# Out:
# 18

# %%
df['Purchase'].unique()
# Out:
# array([ 8370, 15200,  1422, ..., 14539, 11120, 18426], dtype=int64)

# %%
df['Purchase'].nunique()
# Out:
# 17959

# %%
df['Purchase'].unique().sum()
# Out:
# 207978938

# %%
df['Purchase'].sum()
# Out:
# 5017668378

# %%
df['Purchase'].sum()/len(df['Purchase'])
# Out:
# 9333.859852635065

# %%
df['Purchase'].unique().sum()/len(df['Purchase'].unique())
# Out:
# 11580.76385099393

# %%
df.columns
# Out:
# Index(['User_ID', 'Product_ID', 'Gender', 'Age', 'Occupation', 'City_Category',
#        'Stay_In_Current_City_Years', 'Marital_Status', 'Product_Category_1',
#        'Purchase'],
#       dtype='object')

# %%
for i in df.columns:
    print(i)
# Out:
# User_ID
# Product_ID
# Gender
# Age
# Occupation
# City_Category
# Stay_In_Current_City_Years
# Marital_Status
# Product_Category_1
# Purchase

# %%
for i in df.columns:
    print(df[i].nunique() ," : ", i)
# Out:
# 5891  :  User_ID
# 3623  :  Product_ID
# 2  :  Gender
# 7  :  Age
# 21  :  Occupation
# 3  :  City_Category
# 5  :  Stay_In_Current_City_Years
# 2  :  Marital_Status
# 18  :  Product_Category_1
# 17959  :  Purchase

# %% [markdown]
# # ANALYSING GENDER COLUMN

# %%
df['Gender']
# Out:
# 0         F
# 1         F
# 2         F
# 3         F
# 4         M
#          ..
# 537572    M
# 537573    M
# 537574    M
# 537575    M
# 537576    M
# Name: Gender, Length: 537577, dtype: object

# %%
d1=len(df[df['Gender']=='M'])

# %%
d2=len(df[df['Gender']=='F'])

# %%
d1,d2
# Out:
# (405380, 132197)

# %%
data=pd.DataFrame([d1,d2],columns=['Ratio'], index=['Male','Female'])

# %%
data
# Out:
#          Ratio
# Male    405380
# Female  132197

# %%
data.plot(y='Ratio',kind='pie')
# Out:
# <AxesSubplot: ylabel='Ratio'>

# %%
data.plot.pie(y='Ratio',figsize=(6,6),autopct='%.2f')
# Out:
# <AxesSubplot: ylabel='Ratio'>

# %%
df.groupby('Gender').size()
# Out:
# Gender
# F    132197
# M    405380
# dtype: int64

# %%
df.groupby('Gender').size().plot(kind='pie',autopct='%.2f',title='Gender Ratio')
# Out:
# <AxesSubplot: title={'center': 'Gender Ratio'}>

# %%
df.groupby('Gender').sum()
# Out:
# C:\Users\MSI-1\AppData\Local\Temp\ipykernel_6352\1966657182.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby('Gender').sum()
#              User_ID  Occupation  Marital_Status  Product_Category_1  \
# Gender
# F       132605172667      891361           55223              739701
# M       406580175483     3453718          164537             2107063
#
#           Purchase
# Gender
# F       1164624021
# M       3853044357

# %%
df.groupby('Gender').sum()['Purchase']
# Out:
# C:\Users\MSI-1\AppData\Local\Temp\ipykernel_6352\978566082.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby('Gender').sum()['Purchase']
# Gender
# F    1164624021
# M    3853044357
# Name: Purchase, dtype: int64

# %%
df.groupby('Gender').sum()['Purchase'].plot(kind='pie',figsize=(6,6),autopct='%.2f')
# Out:
# C:\Users\MSI-1\AppData\Local\Temp\ipykernel_6352\2499183951.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby('Gender').sum()['Purchase'].plot(kind='pie',figsize=(6,6),autopct='%.2f')
# <AxesSubplot: ylabel='Purchase'>

# %%
df.groupby('Gender').mean()
# Out:
# C:\Users\MSI-1\AppData\Local\Temp\ipykernel_6352\3774296011.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby('Gender').mean()
#              User_ID  Occupation  Marital_Status  Product_Category_1  \
# Gender
# F       1.003088e+06    6.742672        0.417733            5.595445
# M       1.002961e+06    8.519705        0.405883            5.197748
#
#            Purchase
# Gender
# F       8809.761349
# M       9504.771713

# %%
df.groupby('Gender').mean()['Purchase'].plot(kind='pie',figsize=(6,6),autopct='%.2f')
# Out:
# C:\Users\MSI-1\AppData\Local\Temp\ipykernel_6352\2617953650.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby('Gender').mean()['Purchase'].plot(kind='pie',figsize=(6,6),autopct='%.2f')
# <AxesSubplot: ylabel='Purchase'>

# %% [markdown]
# # ANALYZING AGE & MARITAL STATUS

# %%
df.groupby('Age').size()
# Out:
# Age
# 0-17      14707
# 18-25     97634
# 26-35    214690
# 36-45    107499
# 46-50     44526
# 51-55     37618
# 55+       20903
# dtype: int64

# %%
df['Age']
# Out:
# 0          0-17
# 1          0-17
# 2          0-17
# 3          0-17
# 4           55+
#           ...
# 537572    36-45
# 537573    36-45
# 537574    36-45
# 537575    36-45
# 537576    36-45
# Name: Age, Length: 537577, dtype: object

# %%
df['Age'].unique()
# Out:
# array(['0-17', '55+', '26-35', '46-50', '51-55', '36-45', '18-25'],
#       dtype=object)

# %%
df.groupby('Age').size().plot(kind='bar',figsize=(8,4),title='Purchase Distribution By Age')
# Out:
# <AxesSubplot: title={'center': 'Purchase Distribution By Age'}, xlabel='Age'>

# %%
df
# Out:
#         User_ID Product_ID Gender    Age  Occupation City_Category  \
# 0       1000001  P00069042      F   0-17          10             A
# 1       1000001  P00248942      F   0-17          10             A
# 2       1000001  P00087842      F   0-17          10             A
# 3       1000001  P00085442      F   0-17          10             A
# 4       1000002  P00285442      M    55+          16             C
# ...         ...        ...    ...    ...         ...           ...
# 537572  1004737  P00193542      M  36-45          16             C
# 537573  1004737  P00111142      M  36-45          16             C
# 537574  1004737  P00345942      M  36-45          16             C
# 537575  1004737  P00285842      M  36-45          16             C
# 537576  1004737  P00118242      M  36-45          16             C
#
#        Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                               2               0                   3
# ...

# %%
for i in df['Age'].unique():
    print(i)
# Out:
# 0-17
# 55+
# 26-35
# 46-50
# 51-55
# 36-45
# 18-25

# %%
len(df[df['Age']==i])
# Out:
# 97634

# %%
for i in df['Age'].unique():
    print(i," : ",len(df[df['Age']==i]))
# Out:
# 0-17  :  14707
# 55+  :  20903
# 26-35  :  214690
# 46-50  :  44526
# 51-55  :  37618
# 36-45  :  107499
# 18-25  :  97634

# %%
df[['Age','Product_ID']]
# Out:
#           Age Product_ID
# 0        0-17  P00069042
# 1        0-17  P00248942
# 2        0-17  P00087842
# 3        0-17  P00085442
# 4         55+  P00285442
# ...       ...        ...
# 537572  36-45  P00193542
# 537573  36-45  P00111142
# 537574  36-45  P00345942
# 537575  36-45  P00285842
# 537576  36-45  P00118242
#
# [537577 rows x 2 columns]

# %%
df[df['Age']==i]['Product_ID']
# Out:
# 70        P00366542
# 71        P00190742
# 72        P00151842
# 73        P00112642
# 74        P00118442
#             ...
# 537566    P00048742
# 537567    P00157542
# 537568    P00250642
# 537569    P00023142
# 537570    P00162442
# Name: Product_ID, Length: 97634, dtype: object

# %%
len(df[df['Age']==i]['Product_ID'].unique())
# Out:
# 3213

# %%
for i in df['Age'].unique():
    print(i,":",df[df['Age']==i]['Product_ID'].nunique())
# Out:
# 0-17 : 2300
# 55+ : 2573
# 26-35 : 3419
# 46-50 : 3099
# 51-55 : 2877
# 36-45 : 3318
# 18-25 : 3213

# %%
lst=[]
for i in df['Age'].unique():
    lst.append([i,df[df['Age']==i]['Product_ID'].nunique()])

# %%
lst
# Out:
# [['0-17', 2300],
#  ['55+', 2573],
#  ['26-35', 3419],
#  ['46-50', 3099],
#  ['51-55', 2877],
#  ['36-45', 3318],
#  ['18-25', 3213]]

# %%
data=pd.DataFrame(lst,columns=['Age','Products'])

# %%
data
# Out:
#      Age  Products
# 0   0-17      2300
# 1    55+      2573
# 2  26-35      3419
# 3  46-50      3099
# 4  51-55      2877
# 5  36-45      3318
# 6  18-25      3213

# %%
data.plot(kind='bar',x='Age')
# Out:
# <AxesSubplot: xlabel='Age'>

# %%
data.plot.bar(x="Age")
# Out:
# <AxesSubplot: xlabel='Age'>

# %%
df.groupby('Age').sum()
# Out:
# C:\Users\MSI-1\AppData\Local\Temp\ipykernel_6352\160472478.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby('Age').sum()
#             User_ID  Occupation  Marital_Status  Product_Category_1  \
# Age
# 0-17    14746359773      129278               0               72599
# 18-25   97904093780      657774           20641              488498
# 26-35  215350137743     1696554           84166             1120056
# 36-45  107824726995      951060           42507              579163
# 46-50   44666364150      379645           32194              250663
# 51-55   37728982395      331396           26979              212529
# 55+     20964683314      199372           13273              123256
#
#          Purchase
# Age
# 0-17    132659006
# 18-25   901669280
# 26-35  1999749106
# ...

# %%
df.groupby('Age').sum()['Purchase']
# Out:
# C:\Users\MSI-1\AppData\Local\Temp\ipykernel_6352\2397059530.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby('Age').sum()['Purchase']
# Age
# 0-17      132659006
# 18-25     901669280
# 26-35    1999749106
# 36-45    1010649565
# 46-50     413418223
# 51-55     361908356
# 55+       197614842
# Name: Purchase, dtype: int64

# %%
df.head()
# Out:
#    User_ID Product_ID Gender   Age  Occupation City_Category  \
# 0  1000001  P00069042      F  0-17          10             A
# 1  1000001  P00248942      F  0-17          10             A
# 2  1000001  P00087842      F  0-17          10             A
# 3  1000001  P00085442      F  0-17          10             A
# 4  1000002  P00285442      M   55+          16             C
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  Purchase
# 0                          2               0                   3      8370
# 1                          2               0                   1     15200
# 2                          2               0                  12      1422
# 3                          2               0                  12      1057
# 4                         4+               0                   8      7969

# %%
df.groupby('Age').sum()['Purchase'].plot(kind='bar',figsize=(6,6),title='Amount Spend by Age')
# Out:
# C:\Users\MSI-1\AppData\Local\Temp\ipykernel_6352\441421636.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby('Age').sum()['Purchase'].plot(kind='bar',figsize=(6,6),title='Amount Spend by Age')
# <AxesSubplot: title={'center': 'Amount Spend by Age'}, xlabel='Age'>

# %%
df.groupby('Age').mean()['Purchase'].plot(kind='bar',figsize=(6,6),title='Amount Spend by Age')
# Out:
# C:\Users\MSI-1\AppData\Local\Temp\ipykernel_6352\3607668764.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby('Age').mean()['Purchase'].plot(kind='bar',figsize=(6,6),title='Amount Spend by Age')
# <AxesSubplot: title={'center': 'Amount Spend by Age'}, xlabel='Age'>

# %%
df.groupby('Age').sum()['Purchase'].plot(kind='pie', autopct="%0.2f",title='Amount Spend by Age')
# Out:
# C:\Users\MSI-1\AppData\Local\Temp\ipykernel_6352\1761545478.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby('Age').sum()['Purchase'].plot(kind='pie', autopct="%0.2f",title='Amount Spend by Age')
# <AxesSubplot: title={'center': 'Amount Spend by Age'}, ylabel='Purchase'>

# %%
df.groupby('Age').mean()['Purchase'].plot(kind='pie', autopct="%0.2f",title='Amount Spend by Age')
# Out:
# C:\Users\MSI-1\AppData\Local\Temp\ipykernel_6352\3994135547.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby('Age').mean()['Purchase'].plot(kind='pie', autopct="%0.2f",title='Amount Spend by Age')
# <AxesSubplot: title={'center': 'Amount Spend by Age'}, ylabel='Purchase'>

# %%
df.groupby('Marital_Status').size().plot(kind='pie', autopct="%0.2f")
# Out:
# <AxesSubplot: >

# %%
df.groupby('Gender').size().plot(kind='pie', autopct="%0.2f")
# Out:
# <AxesSubplot: >

# %% [markdown]
# # MULTI COLUMN ANALYSIS

# %%
import seaborn as sns

# %%
sns.countplot(x='Age',hue='Gender',data=df)
# Out:
# <AxesSubplot: xlabel='Age', ylabel='count'>

# %%
sns.set(rc={'figure.figsize':(8,6)})
sns.countplot(x='Gender',hue='Age',data=df)
# Out:
# <AxesSubplot: xlabel='Gender', ylabel='count'>

# %%
sns.set(rc={'figure.figsize':(8,6)})
sns.countplot(x='Marital_Status',hue='Gender',data=df)
# Out:
# <AxesSubplot: xlabel='Marital_Status', ylabel='count'>

# %%
sns.countplot(x=df.City_Category)
# Out:
# <AxesSubplot: xlabel='City_Category', ylabel='count'>

# %%
sns.countplot(x=df['City_Category'])
# Out:
# <AxesSubplot: xlabel='City_Category', ylabel='count'>

# %%
df.groupby('City_Category').size().plot(kind='pie',autopct="%0.2f")
# Out:
# <AxesSubplot: >

# %%
df.groupby('City_Category').sum()['Purchase'].plot(kind='pie',autopct="%0.2f")
# Out:
# C:\Users\MSI-1\AppData\Local\Temp\ipykernel_6352\3610991222.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby('City_Category').sum()['Purchase'].plot(kind='pie',autopct="%0.2f")
# <AxesSubplot: ylabel='Purchase'>

# %%
sns.countplot(x='City_Category',hue='Age',data=df)
# Out:
# <AxesSubplot: xlabel='City_Category', ylabel='count'>

# %%
sns.countplot(x='Marital_Status',hue='City_Category',data=df)
# Out:
# <AxesSubplot: xlabel='Marital_Status', ylabel='count'>

# %%
sns.countplot(x='City_Category',hue='Gender',data=df)
# Out:
# <AxesSubplot: xlabel='City_Category', ylabel='count'>

# %%
df.groupby('City_Category').sum()['Purchase'].plot(kind='bar');
# Out:
# C:\Users\MSI-1\AppData\Local\Temp\ipykernel_6352\3228565855.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby('City_Category').sum()['Purchase'].plot(kind='bar');

# %%
df.groupby('City_Category').mean()['Purchase'].plot(kind='pie',autopct="%0.2f");
# Out:
# C:\Users\MSI-1\AppData\Local\Temp\ipykernel_6352\4056116865.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby('City_Category').mean()['Purchase'].plot(kind='pie',autopct="%0.2f");

# %% [markdown]
# # OCCUPATION AND PRODUCTS ANALYSIS

# %%
df.head()
# Out:
#    User_ID Product_ID Gender   Age  Occupation City_Category  \
# 0  1000001  P00069042      F  0-17          10             A
# 1  1000001  P00248942      F  0-17          10             A
# 2  1000001  P00087842      F  0-17          10             A
# 3  1000001  P00085442      F  0-17          10             A
# 4  1000002  P00285442      M   55+          16             C
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  Purchase
# 0                          2               0                   3      8370
# 1                          2               0                   1     15200
# 2                          2               0                  12      1422
# 3                          2               0                  12      1057
# 4                         4+               0                   8      7969

# %%
sns.countplot(x='Stay_In_Current_City_Years',data=df);

# %%
sns.countplot(x='Stay_In_Current_City_Years',hue='Gender',data=df);

# %%
sns.countplot(x='Stay_In_Current_City_Years',hue='Marital_Status',data=df);

# %%
sns.countplot(x='Stay_In_Current_City_Years',hue='City_Category',data=df);

# %%
sns.countplot(x = 'City_Category', hue = 'Age',data = df);

# %%
df.groupby('Stay_In_Current_City_Years').sum()['Purchase'].plot(kind = 'bar');
# Out:
# C:\Users\MSI-1\AppData\Local\Temp\ipykernel_6352\734339259.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby('Stay_In_Current_City_Years').sum()['Purchase'].plot(kind = 'bar');

# %%
df.groupby('Stay_In_Current_City_Years').mean()['Purchase'].plot(kind = 'bar')
# Out:
# C:\Users\MSI-1\AppData\Local\Temp\ipykernel_6352\1632985777.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby('Stay_In_Current_City_Years').mean()['Purchase'].plot(kind = 'bar')
# <AxesSubplot: xlabel='Stay_In_Current_City_Years'>

# %%
sns.countplot(x = df['Occupation'])
# Out:
# <AxesSubplot: xlabel='Occupation', ylabel='count'>

# %%
df.groupby('Occupation').size().plot(kind = 'bar')
# Out:
# <AxesSubplot: xlabel='Occupation'>

# %%
df.groupby('Occupation').size().sort_values().plot(kind = 'bar')
# Out:
# <AxesSubplot: xlabel='Occupation'>

# %%
df.groupby('Occupation').sum()['Purchase'].sort_values().plot(kind = 'bar')
# Out:
# C:\Users\MSI-1\AppData\Local\Temp\ipykernel_6352\2195280667.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby('Occupation').sum()['Purchase'].sort_values().plot(kind = 'bar')
# <AxesSubplot: xlabel='Occupation'>

# %%
df.groupby('Occupation').mean()['Purchase'].sort_values()
# Out:
# C:\Users\MSI-1\AppData\Local\Temp\ipykernel_6352\3915541376.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby('Occupation').mean()['Purchase'].sort_values()
# Occupation
# 9     8714.335934
# 19    8754.249162
# 20    8881.099514
# 1     9017.703095
# 2     9025.938982
# 10    9052.836410
# 0     9186.946726
# 18    9233.671418
# 3     9238.077277
# 4     9279.026742
# 11    9299.467190
# 6     9336.378620
# 5     9388.848978
# 13    9424.449391
# 16    9457.133118
# 7     9502.175276
# 14    9568.536426
# 8     9576.508530
# 15    9866.239925
# 12    9883.052460
# 17    9906.378997
# Name: Purchase, dtype: float64

# %%
df.groupby('Occupation').mean()['Purchase'].sort_values().plot(kind = 'bar')
# Out:
# C:\Users\MSI-1\AppData\Local\Temp\ipykernel_6352\836120488.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby('Occupation').mean()['Purchase'].sort_values().plot(kind = 'bar')
# <AxesSubplot: xlabel='Occupation'>

# %%
sns.countplot(x = 'Occupation', hue = 'Marital_Status', data = df)
# Out:
# <AxesSubplot: xlabel='Occupation', ylabel='count'>

# %%
sns.countplot(x = 'Occupation', hue = 'Gender', data = df)
# Out:
# <AxesSubplot: xlabel='Occupation', ylabel='count'>

# %%
df.groupby('Occupation').nunique()['Product_ID']
# Out:
# Occupation
# 0     3243
# 1     3020
# 2     2892
# 3     2657
# 4     3174
# 5     2344
# 6     2724
# 7     3070
# 8     1026
# 9     1820
# 10    2110
# 11    2235
# 12    2664
# 13    1946
# 14    2680
# 15    2168
# 16    2863
# 17    2831
# 18    2047
# 19    2303
# 20    3147
# Name: Product_ID, dtype: int64

# %%
df.groupby('Occupation').nunique()['Product_ID'].sort_values().plot(kind = 'bar')
# Out:
# <AxesSubplot: xlabel='Occupation'>

# %%
df.groupby('Product_Category_1').size()
# Out:
# Product_Category_1
# 1     138353
# 2      23499
# 3      19849
# 4      11567
# 5     148592
# 6      20164
# 7       3668
# 8     112132
# 9        404
# 10      5032
# 11     23960
# 12      3875
# 13      5440
# 14      1500
# 15      6203
# 16      9697
# 17       567
# 18      3075
# dtype: int64

# %%
df.groupby('Product_Category_1').size().plot(kind = 'bar')
# Out:
# <AxesSubplot: xlabel='Product_Category_1'>

# %%
df.groupby('Product_Category_1').size().sort_values().plot(kind = 'bar')
# Out:
# <AxesSubplot: xlabel='Product_Category_1'>

# %%
df.groupby('Product_Category_1').sum()['Purchase'].sort_values().plot(kind = 'bar')
# Out:
# C:\Users\MSI-1\AppData\Local\Temp\ipykernel_6352\2703638129.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby('Product_Category_1').sum()['Purchase'].sort_values().plot(kind = 'bar')
# <AxesSubplot: xlabel='Product_Category_1'>

# %%
df.groupby('Product_Category_1').mean()['Purchase'].sort_values().plot(kind = 'bar')
# Out:
# C:\Users\MSI-1\AppData\Local\Temp\ipykernel_6352\2965010995.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby('Product_Category_1').mean()['Purchase'].sort_values().plot(kind = 'bar')
# <AxesSubplot: xlabel='Product_Category_1'>

# %%
df.groupby('Product_ID').sum()['Purchase'].nlargest(15).sort_values().plot(kind = 'bar')
# Out:
# C:\Users\MSI-1\AppData\Local\Temp\ipykernel_6352\2176401483.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby('Product_ID').sum()['Purchase'].nlargest(15).sort_values().plot(kind = 'bar')
# <AxesSubplot: xlabel='Product_ID'>

# %%
df.groupby('Product_ID').size().nlargest(10).sort_values().plot(kind = 'bar')
# Out:
# <AxesSubplot: xlabel='Product_ID'>

# %%
df.groupby('Product_ID').mean()['Purchase'].nlargest(10).sort_values().plot(kind = 'bar')
# Out:
# C:\Users\MSI-1\AppData\Local\Temp\ipykernel_6352\485863399.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby('Product_ID').mean()['Purchase'].nlargest(10).sort_values().plot(kind = 'bar')
# <AxesSubplot: xlabel='Product_ID'>

# %%
sns.countplot(x = 'Product_Category_1', hue = 'Gender', data = df)
# Out:
# <AxesSubplot: xlabel='Product_Category_1', ylabel='count'>

# %%
sns.countplot(x = 'Product_Category_1', hue = 'Marital_Status', data = df)
# Out:
# <AxesSubplot: xlabel='Product_Category_1', ylabel='count'>

# %% [markdown]
# #  COMBINING GENDER & MARITAL STATUS

# %%
l = []
for i in range(len(df)):
    l.append(df['Gender'][i] +"_"+ str(df['Marital_Status'][i]))

df['MaritalGender'] = l

# %%
df.head()
# Out:
#    User_ID Product_ID Gender   Age  Occupation City_Category  \
# 0  1000001  P00069042      F  0-17          10             A
# 1  1000001  P00248942      F  0-17          10             A
# 2  1000001  P00087842      F  0-17          10             A
# 3  1000001  P00085442      F  0-17          10             A
# 4  1000002  P00285442      M   55+          16             C
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  Purchase  \
# 0                          2               0                   3      8370
# 1                          2               0                   1     15200
# 2                          2               0                  12      1422
# 3                          2               0                  12      1057
# 4                         4+               0                   8      7969
#
#   MaritalGender
# 0           F_0
# 1           F_0
# 2           F_0
# 3           F_0
# 4           M_0

# %%
sns.countplot(x = df['MaritalGender'])
# Out:
# <AxesSubplot: xlabel='MaritalGender', ylabel='count'>

# %%
sns.countplot(x = df['Age'], hue = df['MaritalGender'])
# Out:
# <AxesSubplot: xlabel='Age', ylabel='count'>

# %%
sns.countplot(x = df['Product_Category_1'], hue = df['MaritalGender'])
# Out:
# <AxesSubplot: xlabel='Product_Category_1', ylabel='count'>

# %%
sns.countplot(x = df['Stay_In_Current_City_Years'], hue = df['MaritalGender'])
# Out:
# <AxesSubplot: xlabel='Stay_In_Current_City_Years', ylabel='count'>

# %%
sns.countplot(x = df['City_Category'], hue = df['MaritalGender'])
# Out:
# <AxesSubplot: xlabel='City_Category', ylabel='count'>
